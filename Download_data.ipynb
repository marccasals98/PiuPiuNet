# %% [markdown]
# <a href="https://colab.research.google.com/github/marccasals98/PiuPiuNet/blob/main/Download_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Download bird songs
# A script to download bird sound files from the www.xeno-canto.org archives with metadata
# The program downloads all the files found with the search terms into subdirectory data/xeno-canto-dataset/searchTerm with corresponding json files.

# %%
import urllib.request, json
import sys
import os

bPath = "../data-fixed/xeno-canto-dataset-full-all-Countries/"
basePath = "../data-fixed/xeno-canto-dataset-full-all-Countries/"

# %% [markdown]
# ## Defining necessary functions
# * Creates the subdirectory data/xeno-canto-dataset if necessary
# * Downloads and saves json files for number of pages in a query
# * and directory path to saved json's

# %%
def save_json(searchTerms, birdName, country):
    numPages = 1
    page = 1
    # create a path to save json files and recordings
    path = bPath + birdName+ "/" + country
    if not os.path.exists(path):
        print("Creating subdirectory " + path + " for downloaded files...")
        os.makedirs(path)
        # download a json file for every page found in a query
    while page < numPages + 1:
        print("Loading page " + str(page) + "...")
        url = 'https://www.xeno-canto.org/api/2/recordings?query={0}&page={1}'.format(searchTerms.replace(' ', '%20'),
                                                                                      page)
        print(url)
        jsonPage = urllib.request.urlopen(url)
        jsondata = json.loads(jsonPage.read().decode('utf-8'))
        filename = path + "/jsondata_p" + str(page) + ".json"
        with open(filename, 'w') as outfile:
            json.dump(jsondata, outfile)
        # check number of pages
        numPages = jsondata['numPages']
        page = page + 1
    print("Found ", numPages, " pages in total.")
    # return number of files in json
    # each page contains 500 results, the last page can have less than 500 records
    print("Saved json for ", (numPages - 1) * 500 + len(jsondata['recordings']), " files")
    return path


# reads the json and return the list of values for selected json part
# i.e. "id" - ID number, "type": type of the bird sound such as call or song
# for all Xeno Canto files found with the given search terms.
def read_data(searchTerm, path):
    data = []
    numPages = 1
    page = 1
    # read all pages and save results in a list
    while page < numPages + 1:
        # read file
        with open(path + "/jsondata_p" + str(page) + ".json", 'r') as jsonfile:
            jsondata = jsonfile.read()
        jsondata = json.loads(jsondata)
        # check number of pages
        numPages = jsondata['numPages']
        # find "recordings" in a json and save a list with a search term
        for k in range(len(jsondata['recordings'])):
            data.append(jsondata["recordings"][k][searchTerm])
        page = page + 1
    return data


# downloads all sound files found with the search terms into xeno-canto directory
# into catalogue named after the search term (i.e. Apus apus)
# filename have two parts: the name of the bird in latin and ID number
def download(searchTerms, birdName, country):
    # create data/xeno-canto-dataset directory
    path = save_json(searchTerms, birdName, country)
    # get filenames: recording ID and bird name in latin from json
    filenamesID = read_data('id', path)
    filenamesCountry = read_data('cnt', path)
    # get website recording http download address from json
    fileaddress = read_data('file', path)
    numfiles = len(filenamesID)
    print("A total of ", numfiles, " files will be downloaded")
    for i in range(0, numfiles):
        print("Saving file ", i + 1, "/", numfiles,
              basePath + birdName.replace(':', '') + filenamesID[
                  i] + ".mp3")      
        urllib.request.urlretrieve(fileaddress[i], path + "/" + birdName + filenamesID[i] + ".mp3")

# %% [markdown]
# ## Download
# Example download with all sounds type song, from bird list recorded in selected countries
#
# *example query*: query = "Dendrocopos major cnt:Poland type:song"
# can be downloaded as:
#
# download(query)
#
# Other options can be specified according to xeno-canto query list
# http://www.xeno-canto.org/explore?query=common+snipe

# %%
countries = ['Spain']
'''
birds = ['Dendrocopos major',
         'Chloris chloris',
         'Corvus frugilegus',
         'Coccothraustes coccothraustes',
         'Columba palumbus',
         'Delichon urbicum',
         'Apus apus',
         'Sitta europaea',
         'Corvus monedula',
         'Phoenicurus ochruros',
         'Turdus merula',
         'Turdus pilaris',
         'Passer montanus',
         'Phylloscopus trochilus',
         'Phylloscopus collybita',
         'Phoenicurus phoenicurus',
         'Motacilla alba',
         'Erithacus rubecula',
         'Streptopelia decaocto',
         'Parus major',
         'Parus caeruleus',
         'Alauda arvensis',
         'Luscinia luscinia',
         'Garrulus glandarius',
         'Turdus philomelos',
         'Pica pica',
         'Troglodytes troglodytes',
         'Carduelis carduelis',
         'Sturnus vulgaris',
         'Emberiza citrinella',
         'Passer domesticus',
         'Corvus corone',
         'Fringilla coelebs']
'''

birds = ['Turdus merula',
         #'Passer domesticus',
         #'Carduelis carduelis',
         #'Sturnus unicolor',
         #'Motacilla alba',
         #'Upupa epops',
         #'Pica pica',
         #'Erithacus rubecula',
         #'Carduelis cannabina',
         #'Galerida cristata',
         #'Miliaria calandra' 
]

'''
birds = ['Sturnus unicolor',
         'Upupa epops',
         'Pica pica',
         'Carduelis cannabina',
         'Miliaria calandra',
         'Merops apiaster'
]
'''
'''
birds = ['Carduelis cannabina',
         'Miliaria calandra',
         'Merops apiaster'
]
'''
for country in countries:
    for bird in birds:
        download(bird + ' cnt:' + country + '&type:song', bird.replace(' ', ''), country)

# %%
# %matplotlib inline
import matplotlib
matplotlib.interactive(False)
matplotlib.use('Agg')

# find all of the files in the directory
import os
import gc
basePath="../data-fixed/xeno-canto-dataset-full-all-Countries/"
melsPath= "../data-fixed/mels-27class/"

birds=[] # list of all birds
for root, dirs, files in os.walk(basePath):
    if root == basePath:
        birds=dirs
birds50=[]                
flist=[] # list of all files
blist=[] # list of files for one bird 
i50=0;
for i, bird in enumerate(birds):
    for root, dirs, files in os.walk(basePath+bird):
        for file in files:
            if file.endswith(".mp3"):
                blist.append(os.path.join(root, file))
    if len(blist) > 50:
        i50 = i50+1;
        print(i50, ". Found ", len(blist), ' files for ', bird ,'(',i+1,')')
        birds50.append(bird)
        flist.append(blist)
    blist=[]
print(birds50) 
print(root)
# Out:
# 1 . Found  130  files for  Meropsapiaster ( 1 )
# ['Meropsapiaster']
# ../data-fixed/xeno-canto-dataset-full-all-Countries/Cardueliscannabina/Spain

# %%
def saveMel(signal, directory):
    gc.enable()
    # MK_spectrogram modified
    N_FFT = 1024         # 
    HOP_SIZE = 1024      #  
    N_MELS = 128          # Higher   
    WIN_SIZE = 1024      # 
    WINDOW_TYPE = 'hann' # 
    FEATURE = 'mel'      # 
    FMIN = 1400

    fig = plt.figure(1,frameon=False)
    fig.set_size_inches(6,6)

    ax = plt.Axes(fig, [0., 0., 1., 1.])
    ax.set_axis_off()
    fig.add_axes(ax)
    
    S = librosa.feature.melspectrogram(y=signal, sr=sr,
                                        n_fft=N_FFT,
                                        hop_length=HOP_SIZE, 
                                        n_mels=N_MELS, 
                                        htk=True, 
                                        fmin=FMIN, # higher limit ##high-pass filter freq.
                                        fmax=sr/2) # AMPLITUDE
    librosa.display.specshow(librosa.power_to_db(S**2,ref=np.max), fmin=FMIN) #power = S**2

    fig.savefig(directory)
    plt.ioff()
    #plt.show(block=False)
    fig.clf()
    ax.cla()
    plt.clf()
    plt.close('all')

# %%
import warnings
warnings.filterwarnings('ignore')

import sys
from tqdm import tqdm_notebook as tqdm
import librosa
import librosa.display
import numpy as np
import matplotlib.pyplot as plt

size = {'desired': 5, # [seconds]
        'minimum': 4, # [seconds]
        'stride' : 0, # [seconds]
        'name': 5 # [number of letters]
       } # stride should not be bigger than desired length

print('Number of directories to check and cut: ', len(flist))

#step = (size['desired']-size['stride'])*sr # length of step between two cuts in seconds
step=1
if step>0:
    for bird, birdList in enumerate(flist):
        print("Processing ",bird,'. ', birds50[bird], "...")
        for birdnr, path in tqdm(enumerate(birdList)):
            # load the mp3 file
            directory=melsPath+str(bird)+birds50[bird][:size['name']]+"/"

            if not os.path.exists(directory):
                os.makedirs(directory)
                
            if not os.path.exists(directory+path.rsplit('/',1)[1].replace(' ', '')[:-4]+"1_1.png"):
                  
                signal, sr = librosa.load(path) # sr = sampling rate
                step = (size['desired']-size['stride'])*sr # length of step between two cuts in seconds
                
                nr=0;
                for start, end in zip(range(0,len(signal),step),range(size['desired']*sr,len(signal),step)):
                    # cut file and save each piece
                    nr=nr+1
                    # save the file if its length is higher than minimum
                    if end-start > size['minimum']*sr:
                        melpath=path.rsplit('/',1)[1]
                        melpath=directory+melpath.replace(' ', '')[:-4]+str(nr)+"_"+str(nr)+".png"
                        saveMel(signal[start:end],melpath)
                    #print('New file...',start/sr,' - ',end/sr)
                    #print('Start: ',start,'end: ', end, 'length: ', end-start)
                
            pass
else:    
    print("Error: Stride should be lower than desired length.")
    
print('Number of files after cutting: ')
# Out:
# Number of directories to check and cut:  1
# Processing  0 .  Meropsapiaster ...
# 0it [00:00, ?it/s]
# Number of files after cutting:

# %%
# Test
import matplotlib.image as mpimg
ilist=[]
for root, dirs, fil


es in os.walk(melsPath):
    print(dirs)
    for file in files:
        if file.endswith(".png"):
            ilist.append(os.path.join(root, file))
img=mpimg.imread(ilist[0])
imgplot = plt.imshow(img)
plt.show()
img=mpimg.imread(ilist[100])
imgplot = plt.imshow(img)
plt.show()
img=mpimg.imread(ilist[70])
imgplot = plt.imshow(img)
plt.show()
img=mpimg.imread(ilist[2035])
imgplot = plt.imshow(img)
plt.show()
print("Found ",len(ilist)," files")
# Out:
# ['0Merop']
# []
# Found  3515  files

# %% [markdown]
# ..data-fixed/mels-27class

# %% [markdown]
# /data-fixed/mels-27class

# %%
# !zip -r /content/mels.zip /data-fixed/mels-27class

# %%
from google.colab import files
files.download("mels.zip")

# %% [markdown]
# ### Download all the mp3 files of the provided list of birds from Spain

# %%
countries = ['Spain']

birds = [#'Turdus merula',
         #'Passer domesticus',
         #'Carduelis carduelis',
         #'Sturnus unicolor',
         #'Motacilla alba',
         #'Upupa epops',
         #'Pica pica',
         #'Erithacus rubecula',
         #'Carduelis cannabina', # any samples found
         #'Galerida cristata',
         #'Miliaria calandra' # any samples found
         'Merops apiaster',
]

for country in countries:
    for bird in birds:
        download(bird + ' cnt:' + country + '&type:song', bird.replace(' ', ''), country)
# Out:
# Creating subdirectory ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster/Spain for downloaded files...
# Loading page 1...
# https://www.xeno-canto.org/api/2/recordings?query=Merops%20apiaster%20cnt:Spain&type:song&page=1
# Found  1  pages in total.
# Saved json for  130  files
# A total of  130  files will be downloaded
# Saving file  1 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster746925.mp3
# Saving file  2 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster742422.mp3
# Saving file  3 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster740249.mp3
# Saving file  4 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster740076.mp3
# Saving file  5 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster740074.mp3
# Saving file  6 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster740072.mp3
# Saving file  7 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster739701.mp3
# Saving file  8 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster735959.mp3
# Saving file  9 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster735681.mp3
# Saving file  10 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster730413.mp3
# Saving file  11 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster721759.mp3
# Saving file  12 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster721081.mp3
# Saving file  13 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster698379.mp3
# Saving file  14 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster698377.mp3
# Saving file  15 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster663229.mp3
# Saving file  16 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster655145.mp3
# Saving file  17 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster640425.mp3
# Saving file  18 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster585418.mp3
# Saving file  19 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster579740.mp3
# Saving file  20 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster579522.mp3
# Saving file  21 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster550449.mp3
# Saving file  22 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster449093.mp3
# Saving file  23 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster434820.mp3
# Saving file  24 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster432138.mp3
# Saving file  25 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster430815.mp3
# Saving file  26 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster412441.mp3
# Saving file  27 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster412440.mp3
# Saving file  28 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster392789.mp3
# Saving file  29 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster392197.mp3
# Saving file  30 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster392196.mp3
# Saving file  31 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster392192.mp3
# Saving file  32 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster392186.mp3
# Saving file  33 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster392182.mp3
# Saving file  34 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster381945.mp3
# Saving file  35 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster381944.mp3
# Saving file  36 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster371244.mp3
# Saving file  37 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster334168.mp3
# Saving file  38 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster334164.mp3
# Saving file  39 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster277540.mp3
# Saving file  40 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster253564.mp3
# Saving file  41 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster176139.mp3
# Saving file  42 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster148892.mp3
# Saving file  43 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster148426.mp3
# Saving file  44 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster109276.mp3
# Saving file  45 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster107230.mp3
# Saving file  46 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster747254.mp3
# Saving file  47 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster740073.mp3
# Saving file  48 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster658334.mp3
# Saving file  49 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster645997.mp3
# Saving file  50 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster587761.mp3
# Saving file  51 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster587221.mp3
# Saving file  52 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster585578.mp3
# Saving file  53 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster585275.mp3
# Saving file  54 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster584646.mp3
# Saving file  55 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster581837.mp3
# Saving file  56 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster580953.mp3
# Saving file  57 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster580817.mp3
# Saving file  58 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster578649.mp3
# Saving file  59 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster569980.mp3
# Saving file  60 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster564651.mp3
# Saving file  61 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster561116.mp3
# Saving file  62 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster557353.mp3
# Saving file  63 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster432518.mp3
# Saving file  64 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster432135.mp3
# Saving file  65 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster411976.mp3
# Saving file  66 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster392195.mp3
# Saving file  67 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster392193.mp3
# Saving file  68 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster392191.mp3
# Saving file  69 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster392188.mp3
# Saving file  70 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster392185.mp3
# Saving file  71 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster392184.mp3
# Saving file  72 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster392183.mp3
# Saving file  73 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster388649.mp3
# Saving file  74 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster335028.mp3
# Saving file  75 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster330431.mp3
# Saving file  76 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster330430.mp3
# Saving file  77 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster320068.mp3
# Saving file  78 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster320067.mp3
# Saving file  79 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster287728.mp3
# Saving file  80 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster283862.mp3
# Saving file  81 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster279045.mp3
# Saving file  82 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster236466.mp3
# Saving file  83 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster97194.mp3
# Saving file  84 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster86583.mp3
# Saving file  85 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster61503.mp3
# Saving file  86 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster33995.mp3
# Saving file  87 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster653580.mp3
# Saving file  88 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster646430.mp3
# Saving file  89 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster589272.mp3
# Saving file  90 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster581776.mp3
# Saving file  91 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster578317.mp3
# Saving file  92 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster573602.mp3
# Saving file  93 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster569981.mp3
# Saving file  94 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster498752.mp3
# Saving file  95 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster490637.mp3
# Saving file  96 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster473374.mp3
# Saving file  97 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster399799.mp3
# Saving file  98 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster399798.mp3
# Saving file  99 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster399301.mp3
# Saving file  100 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster392792.mp3
# Saving file  101 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster337595.mp3
# Saving file  102 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster320066.mp3
# Saving file  103 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster284638.mp3
# Saving file  104 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster284637.mp3
# Saving file  105 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster278145.mp3
# Saving file  106 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster277256.mp3
# Saving file  107 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster277255.mp3
# Saving file  108 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster269385.mp3
# Saving file  109 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster268255.mp3
# Saving file  110 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster264356.mp3
# Saving file  111 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster253991.mp3
# Saving file  112 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster179874.mp3
# Saving file  113 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster179615.mp3
# Saving file  114 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster179275.mp3
# Saving file  115 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster179274.mp3
# Saving file  116 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster179272.mp3
# Saving file  117 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster178407.mp3
# Saving file  118 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster551527.mp3
# Saving file  119 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster288048.mp3
# Saving file  120 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster181698.mp3
# Saving file  121 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster181697.mp3
# Saving file  122 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster181696.mp3
# Saving file  123 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster179614.mp3
# Saving file  124 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster179273.mp3
# Saving file  125 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster178406.mp3
# Saving file  126 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster178405.mp3
# Saving file  127 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster176060.mp3
# Saving file  128 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster176059.mp3
# Saving file  129 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster176058.mp3
# Saving file  130 / 130 ../data-fixed/xeno-canto-dataset-full-all-Countries/Meropsapiaster175455.mp3

# %% [markdown]
# ### Splitting mp3 files into Train, Valid and Test. For each bird class split in 80% train, 10% valid and 10% test.

# %%
train_path = os.path.join("/data-fixed", 'train')
if not os.path.exists(train_path):
                os.makedirs(train_path)

valid_path = os.path.join("/data-fixed", 'validation')
if not os.path.exists(valid_path):
                os.makedirs(valid_path)

test_path = os.path.join("/data-fixed", 'test')
if not os.path.exists(test_path):
                os.makedirs(test_path)

# %%
import random
import math
import shutil
'''
birds = ['Turdusmerula',
         'Passerdomesticus',
         'Cardueliscarduelis',
         'Sturnusunicolor',
         'Motacillaalba',
         'Upupaepops',
         'Picapica',
         'Erithacusrubecula',
         'Galeridacristata',
]
''' 
birds = ['Meropsapiaster']
country = "Spain"

val_percentage = 10
test_percentage = 10

for bird_name in birds:

    print(f'---------[{bird_name}]----------')
    mdata_path = os.path.join("/data-fixed/xeno-canto-dataset-full-all-Countries", bird_name, country)

    mp3_files = [f for f in sorted(os.listdir(mdata_path))]
    print(f'We have a total of {len(mp3_files)} mp3 files.')
    random.shuffle(mp3_files) # randomly shuffle the files

    val_samples = math.floor(val_percentage/100*len(mp3_files))
    print(f'We will have {val_samples} mp3 files from {bird_name} on the Validation split')

    test_samples = math.floor(test_percentage/100*len(mp3_files))
    print(f'We will have {test_samples} mp3 files from {bird_name} on the Test split')
    print(f'We will have {len(mp3_files)-val_samples-test_samples} mp3 files from {bird_name} on the Training split')

    for idx, f in enumerate(mp3_files):

      if idx < val_samples: # copy file to validation folder
          destination_path = os.path.join(valid_path, bird_name, country)
          if not os.path.exists(destination_path):
              os.makedirs(destination_path)

          shutil.copyfile(os.path.join(mdata_path, f), os.path.join(destination_path, f))

      elif idx < val_samples + test_samples: # copy file to test folder
          destination_path = os.path.join(test_path, bird_name, country)
          if not os.path.exists(destination_path):
              os.makedirs(destination_path)

          shutil.copyfile(os.path.join(mdata_path, f), os.path.join(destination_path, f))

      else: # copy file to train folder
          destination_path = os.path.join(train_path, bird_name, country)
          if not os.path.exists(destination_path):
              os.makedirs(destination_path)

          shutil.copyfile(os.path.join(mdata_path, f), os.path.join(destination_path, f))
      
    # Check number of samples on each split

    train_files = [f for f in os.listdir(os.path.join(train_path, bird_name, country))]
    valid_files = [f for f in os.listdir(os.path.join(valid_path, bird_name, country))]
    test_files = [f for f in os.listdir(os.path.join(test_path, bird_name, country))]
    print('\nChecking: ...')
    print(f'There are {len(train_files)}/{len(valid_files)}/{len(test_files)} train/valid/test mp3 files of {bird_name}.')
    print("\n------------------------------------------------------------\n")
# Out:
# ---------[Meropsapiaster]----------
# We have a total of 131 mp3 files.
# We will have 13 mp3 files from Meropsapiaster on the Validation split
# We will have 13 mp3 files from Meropsapiaster on the Test split
# We will have 105 mp3 files from Meropsapiaster on the Training split
#
# Checking: ...
# There are 105/13/13 train/valid/test mp3 files of Meropsapiaster.
#
# ------------------------------------------------------------

# %%
# !zip -r /data-fixed/train-data.zip /data-fixed/train/Meropsapiaster
# !zip -r /data-fixed/valid-data.zip /data-fixed/validation/Meropsapiaster
# !zip -r /data-fixed/test-data.zip /data-fixed/test/Meropsapiaster
# Out:
#   adding: data-fixed/train/Meropsapiaster/ (stored 0%)
#   adding: data-fixed/train/Meropsapiaster/Spain/ (stored 0%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster578317.mp3 (deflated 8%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster179274.mp3 (deflated 1%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster33995.mp3 (deflated 10%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster176058.mp3 (deflated 1%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster392185.mp3 (deflated 2%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster430815.mp3 (deflated 2%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster698379.mp3 (deflated 1%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster392184.mp3 (deflated 2%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster61503.mp3 (deflated 4%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster284637.mp3 (deflated 4%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster698377.mp3 (deflated 2%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster320067.mp3 (deflated 1%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster179272.mp3 (deflated 2%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster148426.mp3 (deflated 1%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster653580.mp3 (deflated 5%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster381945.mp3 (deflated 1%)
#   adding: data-fixed/train/Meropsapiaster/Spain/jsondata_p1.json (deflated 89%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster277540.mp3 (deflated 2%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster585578.mp3 (deflated 5%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster412441.mp3 (deflated 1%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster663229.mp3 (deflated 1%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster86583.mp3 (deflated 2%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster432135.mp3 (deflated 23%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster181698.mp3 (deflated 1%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster179614.mp3 (deflated 1%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster175455.mp3 (deflated 1%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster587761.mp3 (deflated 2%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster335028.mp3 (deflated 5%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster181696.mp3 (deflated 2%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster179275.mp3 (deflated 1%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster412440.mp3 (deflated 1%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster392197.mp3 (deflated 1%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster178406.mp3 (deflated 1%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster330431.mp3 (deflated 3%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster432518.mp3 (deflated 2%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster107230.mp3 (deflated 6%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster746925.mp3 (deflated 1%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster371244.mp3 (deflated 4%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster580953.mp3 (deflated 15%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster434820.mp3 (deflated 19%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster279045.mp3 (deflated 4%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster97194.mp3 (deflated 9%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster579740.mp3 (deflated 21%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster381944.mp3 (deflated 2%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster551527.mp3 (deflated 1%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster181697.mp3 (deflated 1%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster288048.mp3 (deflated 6%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster735959.mp3 (deflated 1%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster655145.mp3 (deflated 4%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster278145.mp3 (deflated 5%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster277255.mp3 (deflated 4%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster178407.mp3 (deflated 0%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster580817.mp3 (deflated 2%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster109276.mp3 (deflated 2%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster645997.mp3 (deflated 1%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster589272.mp3 (deflated 6%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster392195.mp3 (deflated 2%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster320066.mp3 (deflated 2%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster392193.mp3 (deflated 2%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster735681.mp3 (deflated 4%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster581776.mp3 (deflated 1%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster432138.mp3 (deflated 23%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster284638.mp3 (deflated 5%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster392789.mp3 (deflated 2%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster283862.mp3 (deflated 5%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster179615.mp3 (deflated 1%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster490637.mp3 (deflated 5%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster721081.mp3 (deflated 1%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster578649.mp3 (deflated 1%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster740073.mp3 (deflated 1%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster264356.mp3 (deflated 6%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster392183.mp3 (deflated 2%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster176139.mp3 (deflated 22%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster569980.mp3 (deflated 9%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster399301.mp3 (deflated 4%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster236466.mp3 (deflated 2%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster747254.mp3 (deflated 18%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster584646.mp3 (deflated 1%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster561116.mp3 (deflated 2%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster392182.mp3 (deflated 2%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster392192.mp3 (deflated 2%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster277256.mp3 (deflated 5%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster740074.mp3 (deflated 1%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster569981.mp3 (deflated 8%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster740076.mp3 (deflated 1%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster740072.mp3 (deflated 1%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster399798.mp3 (deflated 2%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster334164.mp3 (deflated 3%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster557353.mp3 (deflated 7%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster334168.mp3 (deflated 7%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster269385.mp3 (deflated 4%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster388649.mp3 (deflated 2%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster587221.mp3 (deflated 4%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster253564.mp3 (deflated 3%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster730413.mp3 (deflated 2%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster392792.mp3 (deflated 1%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster148892.mp3 (deflated 2%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster550449.mp3 (deflated 1%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster498752.mp3 (deflated 2%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster320068.mp3 (deflated 2%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster337595.mp3 (deflated 3%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster740249.mp3 (deflated 4%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster392188.mp3 (deflated 2%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster179874.mp3 (deflated 2%)
#   adding: data-fixed/train/Meropsapiaster/Spain/Meropsapiaster721759.mp3 (deflated 1%)
#   adding: data-fixed/validation/Meropsapiaster/ (stored 0%)
#   adding: data-fixed/validation/Meropsapiaster/Spain/ (stored 0%)
#   adding: data-fixed/validation/Meropsapiaster/Spain/Meropsapiaster392191.mp3 (deflated 2%)
#   adding: data-fixed/validation/Meropsapiaster/Spain/Meropsapiaster579522.mp3 (deflated 1%)
#   adding: data-fixed/validation/Meropsapiaster/Spain/Meropsapiaster178405.mp3 (deflated 1%)
#   adding: data-fixed/validation/Meropsapiaster/Spain/Meropsapiaster585275.mp3 (deflated 5%)
#   adding: data-fixed/validation/Meropsapiaster/Spain/Meropsapiaster739701.mp3 (deflated 3%)
#   adding: data-fixed/validation/Meropsapiaster/Spain/Meropsapiaster564651.mp3 (deflated 1%)
#   adding: data-fixed/validation/Meropsapiaster/Spain/Meropsapiaster411976.mp3 (deflated 2%)
#   adding: data-fixed/validation/Meropsapiaster/Spain/Meropsapiaster330430.mp3 (deflated 3%)
#   adding: data-fixed/validation/Meropsapiaster/Spain/Meropsapiaster585418.mp3 (deflated 1%)
#   adding: data-fixed/validation/Meropsapiaster/Spain/Meropsapiaster179273.mp3 (deflated 1%)
#   adding: data-fixed/validation/Meropsapiaster/Spain/Meropsapiaster392196.mp3 (deflated 1%)
#   adding: data-fixed/validation/Meropsapiaster/Spain/Meropsapiaster473374.mp3 (deflated 23%)
#   adding: data-fixed/validation/Meropsapiaster/Spain/Meropsapiaster253991.mp3 (deflated 1%)
#   adding: data-fixed/test/Meropsapiaster/ (stored 0%)
#   adding: data-fixed/test/Meropsapiaster/Spain/ (stored 0%)
#   adding: data-fixed/test/Meropsapiaster/Spain/Meropsapiaster176059.mp3 (deflated 1%)
#   adding: data-fixed/test/Meropsapiaster/Spain/Meropsapiaster742422.mp3 (deflated 2%)
#   adding: data-fixed/test/Meropsapiaster/Spain/Meropsapiaster176060.mp3 (deflated 1%)
#   adding: data-fixed/test/Meropsapiaster/Spain/Meropsapiaster287728.mp3 (deflated 2%)
#   adding: data-fixed/test/Meropsapiaster/Spain/Meropsapiaster640425.mp3 (deflated 1%)
#   adding: data-fixed/test/Meropsapiaster/Spain/Meropsapiaster573602.mp3 (deflated 2%)
#   adding: data-fixed/test/Meropsapiaster/Spain/Meropsapiaster392186.mp3 (deflated 2%)
#   adding: data-fixed/test/Meropsapiaster/Spain/Meropsapiaster449093.mp3 (deflated 10%)
#   adding: data-fixed/test/Meropsapiaster/Spain/Meropsapiaster581837.mp3 (deflated 1%)
#   adding: data-fixed/test/Meropsapiaster/Spain/Meropsapiaster646430.mp3 (deflated 10%)
#   adding: data-fixed/test/Meropsapiaster/Spain/Meropsapiaster658334.mp3 (deflated 1%)
#   adding: data-fixed/test/Meropsapiaster/Spain/Meropsapiaster268255.mp3 (deflated 5%)
#   adding: data-fixed/test/Meropsapiaster/Spain/Meropsapiaster399799.mp3 (deflated 2%)

# %%
from google.colab import files
files.download("/data-fixed/train-data.zip")
files.download("/data-fixed/valid-data.zip")
files.download("/data-fixed/test-data.zip")
